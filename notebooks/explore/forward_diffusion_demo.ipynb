# %% [markdown]
# # Forward Diffusion

# %%
from src.diffusion_playground.data.toy_datasets import load_toy_dataset
from src.diffusion_playground.diffusion.forward import ForwardDiffusion
from src.diffusion_playground.visualization.plot import plot_trajectory

# %%
# Load a dataset
X = load_toy_dataset("moons", n_samples=500)

# Forward Diffusion
diffusion = ForwardDiffusion(time_steps=50, beta=0.003)
trajectory = diffusion.diffuse(X)

# Visualize
plot_trajectory(trajectory)
